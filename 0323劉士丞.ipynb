# %% [markdown]
# <a href="https://colab.research.google.com/github/EricLiu407/Introduction-to-Computers-/blob/main/0323%E5%8A%89%E5%A3%AB%E4%B8%9E.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('123')
# Out:
# 123

# %% [markdown]
# ![螢幕擷取畫面 2022-04-10 153243.png](data:image/png;base64,...)

# %%
12+3
# Out:
# 15

# %%
12-3
# Out:
# 9

# %%
12*3
# Out:
# 36

# %%
32/5
# Out:
# 6.4

# %%
32%5
# Out:
# 2

# %%
32//5
# Out:
# 6

# %%
7**2
# Out:
# 49

# %%
7**4
# Out:
# 2401

# %%
上底=int(input('請輸入梯形上底長度'))
下底=int(input('請輸入梯形下底長度'))
高=int(input('請輸入梯形高度'))
面積=(上底+下底)*高/2
print('梯形上底長度為',上底,'梯形下底長度為',下底,'梯形高度為',高,'梯形面積為',面積)
# Out:
# 請輸入梯形上底長度3
# 請輸入梯形下底長度4
# 請輸入梯形高度3
# 梯形上底長度為 3 梯形下底長度為 4 梯形高度為 3 梯形面積為 10.5

# %%
print("梯形上底長度為:%d，梯形下底長度為:%d，梯形高為:%d，梯形面積為:%d'%(上底，下底，高，面積)")
# Out:
# 梯形上底長度為:%d，梯形下底長度為:%d，梯形高為:%d，梯形面積為:%d'%(上底，下底，高，面積)

# %%
print("梯形上底長度為:%d，梯形下底長度為:%d，梯形高為:%d，梯形面積為:%f'%(上底，下底，高，面積)")
# Out:
# 梯形上底長度為:%d，梯形下底長度為:%d，梯形高為:%d，梯形面積為:%f'%(上底，下底，高，面積)

# %%
print("梯形上底長度為:%d，梯形下底長度為:%d，梯形高為:%d，梯形面積為:%0.1f'%(上底，下底，高，面積)")
# Out:
# 梯形上底長度為:%d，梯形下底長度為:%d，梯形高為:%d，梯形面積為:%0.1f'%(上底，下底，高，面積)

# %%
a=1.1
b=2.02
c=3.003

# %%
print('a=0.1%f，b=0.2%f，c=0.3%f'%(a,b,,c))
# Out:
#   File "<ipython-input-30-c63778d27cef>", line 1
#     print('a=0.1%f，b=0.2%f，c=0.3%f'%(a,b,,c))
#                                          ^
# SyntaxError: invalid syntax

# %%
height=float(input("請輸入你的身高(cm):"))
weight=float(input("請輸入你的體重(kg):"))
bmi=weight/(height/100)**2
print("身高%d公分，體重%d公斤，bmi值為%.2f")%(height，weight,bmi)
# Out:
#   File "<ipython-input-38-5e0d52932449>", line 4
#     print("身高%d公分，體重%d公斤，bmi值為%.2f")%(height，weight,bmi)
#                                                   ^
# SyntaxError: invalid character in identifier

# %%
1==2
# Out:
# False

# %%
3>2
# Out:
# True

# %%
5<4
# Out:
# False

# %%
7>=5
# Out:
# True

# %%
5<=6
# Out:
# True
